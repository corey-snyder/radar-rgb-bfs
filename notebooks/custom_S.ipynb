# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pickle
import os
import copy
from scipy.ndimage import gaussian_filter1d
from scipy import interpolate
from sklearn.preprocessing import minmax_scale
import PIL

# %%
gt_path = '../RGB_images/groundtruth'
gt_images = []
for ii in range(50):
    gt_images.append(plt.imread(os.path.join(gt_path, 'rgb_%i.png'%ii)))
for pic in gt_images:
    pic[pic>0]=1

# %%
S = np.load('/home/spencer/research/radar-rgb-bfs/output/csl_lobby_700/S_pcp.npy')
S_prime = [S[ii]*gt_images[ii] for ii in range(50)]

# %%
for pic in S_prime:
    plt.imshow(pic)
    plt.show()

# %%
S_prime = np.array(S_prime)
print(S_prime.shape)
np.save('/home/spencer/research/radar-rgb-bfs/output/csl_lobby_700/S_mask_pcp.npy',S_prime)
# Out:
# (50, 720, 1280)
