# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 13})

# %%
l2_radar_mean_700,l2_radar_std_700 = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l2_radar_auc_csl_lobby_700.npy') 
l2_radar_mean_side,l2_radar_std_side = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l2_radar_auc_csl_lobby_side.npy')
l2_radar_mean_pantry,l2_radar_std_pantry = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l2_radar_auc_csl_pantry.npy')
l2_radar_mean_pantry_12,l2_radar_std_pantry_12 = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l2_radar_auc_csl_pantry_12.npy')


l8_radar_mean_700,l8_radar_std_700 = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l8_radar_auc_csl_lobby_700.npy') 
l8_radar_mean_side,l8_radar_std_side = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l8_radar_auc_csl_lobby_side.npy')
l8_radar_mean_pantry,l8_radar_std_pantry = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l8_radar_auc_csl_pantry.npy')
l8_radar_mean_pantry_12,l8_radar_std_pantry_12 = np.load('/home/spencer/research/radar-rgb-bfs/NN/radar/roc_auc/l8_radar_auc_csl_pantry_12.npy')

# %%
l2_og_mean_700,l2_og_std_700 = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l2_og_auc_csl_lobby_700.npy') 
l2_og_mean_side,l2_og_std_side = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l2_og_auc_csl_lobby_side_0.npy')
l2_og_mean_pantry,l2_og_std_pantry = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l2_og_auc_csl_pantry.npy')
l2_og_mean_pantry_12,l2_og_std_pantry_12 = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l2_og_auc_csl_pantry_12.npy')


l8_og_mean_700,l8_og_std_700 = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l8_og_auc_csl_pantry.npy') 
l8_og_mean_side,l8_og_std_side = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l8_og_auc_csl_lobby_side_0.npy')
l8_og_mean_pantry,l8_og_std_pantry = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l8_og_auc_csl_pantry.npy')
l8_og_mean_pantry_12,l8_og_std_pantry_12 = np.load('/home/spencer/research/radar-rgb-bfs/NN/baseline/roc_auc/l8_og_auc_csl_pantry_12.npy')

# %%
x_1 = np.array([1,2,3,4])
baseline_mean = np.array([l2_og_mean_side, l2_og_mean_700,l2_og_mean_pantry, l2_og_mean_pantry_12])
baseline_std = np.array([l2_og_std_side, l2_og_std_700, l2_og_std_pantry,l2_og_std_pantry_12])

x_2 = np.array([1.1,2.1,3.1,4.1])
radar_mean = np.array([l2_radar_mean_side, l2_radar_mean_700,l2_radar_mean_pantry,l2_radar_mean_pantry_12])
radar_std = np.array([l2_radar_std_side, l2_radar_std_700, l2_radar_std_pantry,l2_radar_std_pantry_12])


plt.title('2 Layers')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['CSL SIDE', 'CSL 700',' Pantry','Pantry[:12]']
plt.xticks(x_1, my_xticks)
plt.errorbar(x_1, baseline_mean, yerr=baseline_std, fmt='o',label='Baseline')
plt.errorbar(x_2, radar_mean, yerr=radar_std, fmt='o',label='Radar')
plt.legend(loc='lower left')
plt.savefig('2_layer_auc.png')
plt.show()

# %%
x_1 = np.array([1,2,3,4])
baseline_mean = np.array([l8_og_mean_side, l8_og_mean_700,l8_og_mean_pantry,l8_og_mean_pantry_12])
baseline_std = np.array([l8_og_std_side, l8_og_std_700, l8_og_std_pantry,l8_og_std_pantry_12])

x_2 = np.array([1.1,2.1,3.1,4.1])
radar_mean = np.array([l8_radar_mean_side, l8_radar_mean_700,l8_radar_mean_pantry,l8_radar_mean_pantry_12])
radar_std = np.array([l8_radar_std_side, l8_radar_std_700, l8_radar_std_pantry, l8_radar_std_pantry_12])


plt.title('8 Layers')
plt.ylabel('AUC')
my_xticks = ['  CSL SIDE', 'CSL 700',' Pantry','Pantry[:12]']
plt.xticks(x_1, my_xticks)
plt.tick_params(axis='x', length = 0)
plt.errorbar(x_1, baseline_mean, yerr=baseline_std, fmt='o',label='Baseline')
plt.errorbar(x_2, radar_mean, yerr=radar_std, fmt='o',label='Radar')
plt.legend(loc='lower left')
plt.savefig('8_layer_auc.png')
plt.show()

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 13})

# %% [markdown]
# # SeqLen: 30    Layers: 2    Train: Side

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/radar/len30/train_side/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/baseline/len30/train_side/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.84,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.82,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.80,.95])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.93])
plt.show()

# %% [markdown]
# # SeqLen: 50    Layers: 2    Train: Side

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/radar/len50/train_side/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/baseline/len50/train_side/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.86,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.84,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.75,.99])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.93])
plt.show()

# %% [markdown]
# # SeqLen: 30    Layers: 2    Train: Lobby 700

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/radar/len30/train_lobby_700/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/baseline/len30/train_lobby_700/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.89,.96])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.84,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.80,.92])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.96])
plt.show()

# %% [markdown]
# # SeqLen: 50    Layers: 2    Train: Lobby 700

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/radar/len50/train_lobby_700/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/baseline/len50/train_lobby_700/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.84,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.82,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.75,.92])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.96])
plt.show()
