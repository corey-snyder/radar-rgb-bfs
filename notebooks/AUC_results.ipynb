# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 13})

# %% [markdown]
# # SeqLen: 30    Layers: 2    Train: Side

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/radar/len30/train_side/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/baseline/len30/train_side/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.84,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.82,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.80,.95])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.93])
plt.show()

# %% [markdown]
# # SeqLen: 50    Layers: 2    Train: Side

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/radar/len50/train_side/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/baseline/len50/train_side/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.86,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.84,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.75,.99])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.93])
plt.show()

# %% [markdown]
# # SeqLen: 30    Layers: 2    Train: Lobby 700

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/radar/len30/train_lobby_700/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/baseline/len30/train_lobby_700/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.89,.96])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.84,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.80,.92])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.96])
plt.show()

# %% [markdown]
# # SeqLen: 50    Layers: 2    Train: Lobby 700

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/radar/len50/train_lobby_700/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/2_layers/baseline/len50/train_lobby_700/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('2 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.84,.95])


plt.subplot(222)
plt.title('2 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.82,.92])



plt.subplot(223)
plt.title('2 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.75,.92])


plt.subplot(224)
plt.title('2 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.84,.96])
plt.show()

# %% [markdown]
# # SeqLen: 30    Layers: 8    Train: Side

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/8_layers/radar/len30/train_side/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/8_layers/baseline/len30/train_side/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('8 Layers, Side (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.94,.98])


plt.subplot(222)
plt.title('8 Layers, Lobby700 (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
# plt.ylim([.82,.92])



plt.subplot(223)
plt.title('8 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
# plt.ylim([.80,.95])


plt.subplot(224)
plt.title('8 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
# plt.ylim([.84,.93])
plt.show()

# %% [markdown]
# # SeqLen: 30    Layers: 8    Train: Lobby 700

# %%
os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/8_layers/radar/len30/train_lobby_700/eval')
after_lobby_700_mean, after_lobby_700_std = np.load('after/CSL_lobby_700/AUC.npy')
after_side_0_mean, after_side_0_std = np.load('after/CSL_lobby_side_0/AUC.npy')
after_pantry_mean, after_pantry_std = np.load('after/CSL_pantry/AUC.npy')
after_pantry12_mean, after_pantry12_std = np.load('after/pantry_12/AUC.npy')

before_lobby_700_mean, before_lobby_700_std = np.load('before/CSL_lobby_700/AUC.npy')
before_side_0_mean, before_side_0_std = np.load('before/CSL_lobby_side_0/AUC.npy')
before_pantry_mean, before_pantry_std = np.load('before/CSL_pantry/AUC.npy')
before_pantry12_mean, before_pantry12_std = np.load('before/pantry_12/AUC.npy')

in_lobby_700_mean, in_lobby_700_std = np.load('in/CSL_lobby_700/AUC.npy')
in_side_0_mean, in_side_0_std = np.load('in/CSL_lobby_side_0/AUC.npy')
in_pantry_mean, in_pantry_std = np.load('in/CSL_pantry/AUC.npy')
in_pantry12_mean, in_pantry12_std = np.load('in/pantry_12/AUC.npy')


os.chdir('/home/spencer/research/radar-rgb-bfs/NN/runs/8_layers/baseline/len30/train_lobby_700/eval')
baseline_lobby_700_mean, baseline_lobby_700_std = np.load('CSL_lobby_700/AUC.npy')
baseline_side_0_mean, baseline_side_0_std = np.load('CSL_lobby_side_0/AUC.npy')
baseline_pantry_mean, baseline_pantry_std = np.load('CSL_pantry/AUC.npy')
baseline_pantry12_mean, baseline_pantry12_std = np.load('pantry_12/AUC.npy')

# %%
x = [0,1,2,3]

plt.figure(figsize=(15,10))
plt.subplot(221)
plt.title('8 Layers, Side (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_side_0_mean,before_side_0_mean,after_side_0_mean,baseline_side_0_mean],
             yerr=[in_side_0_std,before_side_0_std,after_side_0_std,baseline_side_0_std], fmt='o')
plt.ylim([.94,.98])


plt.subplot(222)
plt.title('8 Layers, Lobby700 (Train)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_lobby_700_mean,before_lobby_700_mean,after_lobby_700_mean,baseline_lobby_700_mean],
             yerr=[in_lobby_700_std,before_lobby_700_std,after_lobby_700_std,baseline_lobby_700_std], fmt='o')
plt.ylim([.9,.94])



plt.subplot(223)
plt.title('8 Layers, Pantry (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry_mean,before_pantry_mean,after_pantry_mean,baseline_pantry_mean],
             yerr=[in_pantry_std,before_pantry_std,after_pantry_std,baseline_pantry_std], fmt='o')
plt.ylim([.80,.92])


plt.subplot(224)
plt.title('8 Layers, Pantry[:12] (Test)')
plt.ylabel('AUC')
plt.tick_params(axis='x', length = 0)

my_xticks = ['in', 'before',' after','base']
plt.xticks(x, my_xticks)
plt.errorbar(x, [in_pantry12_mean,before_pantry12_mean,after_pantry12_mean,baseline_pantry12_mean],
             yerr=[in_pantry12_std,before_pantry12_std,after_pantry12_std,baseline_pantry12_std], fmt='o')
plt.ylim([.9,.95])
plt.show()
