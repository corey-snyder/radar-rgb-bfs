# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 15})
import matplotlib.patches as patches
from skimage.transform import rescale

# %%
idx = 9
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)
ista = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/S_ista_400_30.npy')[idx])
ista = rescale(ista,(.25,.25),anti_aliasing=True)

baseline_2 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/outputs/BASELINE_l2_lr0.001_ds0.25_seed0_len30__20-05-2021_19-24-05_output.npy')[idx,1])
radar_2 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/outputs/RADAR_after_l2_lr0.001_ds0.25_seed0_len30_cos0__21-05-2021_10-08-49_output.npy')[idx,1])
baseline_8 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/outputs/BASELINE_l8_lr0.001_ds0.25_seed0_len30__23-05-2021_20-44-10_output.npy')[idx,1])
radar_8 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/outputs/RADAR_after_l8_lr0.001_ds0.25_seed0_len30_cos0__24-05-2021_08-29-31_output.npy')[idx,1])

# %%
plt.figure(figsize=(14,6))

plt.subplot(231)
plt.title('Input')
plt.imshow(D, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.subplot(234)
plt.title('ISTA',y=-.15)
plt.imshow(ista, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.subplot(232)
plt.title('2 Layer No Radar')
plt.imshow(baseline_2, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.subplot(235)
plt.title('2 Layer Radar',y=-.15)
plt.imshow(radar_2, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.subplot(233)
plt.title('8 Layer No Radar')
plt.imshow(baseline_8, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.subplot(236)
plt.title('8 Layer Radar',y=-.15)
plt.imshow(radar_8, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])

plt.tight_layout()
# plt.savefig('lobby_700_all.png')
plt.show()

# %%
plt.imshow(D, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_input.png',bbox_inches='tight')


plt.imshow(ista, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_ista.png',bbox_inches='tight')


plt.imshow(baseline_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_baseline_2.png',bbox_inches='tight')


plt.imshow(radar_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_radar_2.png',bbox_inches='tight')


plt.imshow(baseline_8, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_baseline_8.png',bbox_inches='tight')


plt.imshow(radar_8, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('lobby_700_radar_8.png',bbox_inches='tight')

# %%
idx = 1
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)
R = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/radar_likelihoods.npy')[idx]
R = rescale(R,(.25),anti_aliasing=True)
ista = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/S_ista_400_30.npy')[idx])
ista = rescale(ista,(.25,.25),anti_aliasing=True)

baseline_2 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/outputs/BASELINE_l2_lr0.001_ds0.25_seed0_len30__20-05-2021_19-24-05_output.npy')[idx,1])
radar_2 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/outputs/RADAR_after_l2_lr0.001_ds0.25_seed0_len30_cos0__21-05-2021_10-08-49_output.npy')[idx,1])
baseline_8 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/outputs/BASELINE_l8_lr0.001_ds0.25_seed0_len30__23-05-2021_20-44-10_output.npy')[idx,1])
radar_8 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/outputs/RADAR_after_l8_lr0.001_ds0.25_seed0_len30_cos0__24-05-2021_08-29-31_output.npy')[idx,1])

# %%
plt.plot(R)

# %%
plt.figure(figsize=(14,2.5))
rect2 = patches.Rectangle((210, 40), 35, 80, linewidth=1, edgecolor='y', facecolor='none', linestyle='--')
rect3 = patches.Rectangle((210, 40), 35, 80, linewidth=1, edgecolor='y', facecolor='none', linestyle='--')
rect4 = patches.Rectangle((210, 40), 35, 80, linewidth=1, edgecolor='y', facecolor='none', linestyle='--')
plt.subplot(141)
plt.title('Input')
plt.imshow(D, cmap='gray')
plt.plot(-R*80+200,color='lime',linestyle='-',linewidth=2.5,alpha=.8)
plt.xticks([])
plt.yticks([])

ax2=plt.subplot(142)
plt.title('ISTA')
plt.imshow(ista, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax2.add_patch(rect2)

ax3=plt.subplot(143)
plt.title('2 Layer No Radar')
plt.imshow(baseline_2, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax3.add_patch(rect3)

ax4=plt.subplot(144)
plt.title('2 Layer Radar')
plt.imshow(radar_2, cmap='Greys', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax4.add_patch(rect4)

plt.tight_layout()
# plt.savefig('pantry_ghost.png')
plt.show()

# %%
rect2 = patches.Rectangle((210, 40), 35, 80, linewidth=2, edgecolor='y', facecolor='none', linestyle='--')
rect3 = patches.Rectangle((210, 40), 35, 80, linewidth=2, edgecolor='y', facecolor='none', linestyle='--')
rect4 = patches.Rectangle((210, 40), 35, 80, linewidth=2, edgecolor='y', facecolor='none', linestyle='--')

# ax1 = plt.subplot(111)
# plt.imshow(D, cmap='gray')
# plt.plot(-R*80+200,color='lime',linestyle='-',linewidth=2.5,alpha=.8)
# plt.xticks([])
# plt.yticks([])
# plt.savefig('pantry_input_overlay.png',bbox_inches='tight')


ax2 = plt.subplot(111)
plt.imshow(ista, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax2.add_patch(rect2)
plt.savefig('pantry_ista.png',bbox_inches='tight')

ax3 = plt.subplot(111)
plt.imshow(baseline_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax3.add_patch(rect3)
plt.savefig('pantry_baseline_2.png',bbox_inches='tight')


ax4 = plt.subplot(111)
plt.imshow(radar_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
ax4.add_patch(rect4)
plt.savefig('pantry_radar_2.png',bbox_inches='tight')
# Out:
# /home/spencer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/spencer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
idx = 14
radar_2 = np.abs(np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700_coppy/outputs/RADAR_after_l2_lr0.001_ds0.25_seed0_len30_cos0__21-05-2021_10-08-49_output.npy')[idx,1])
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700_coppy/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700_coppy/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

# %%
fig = plt.figure(constrained_layout=False,figsize=(5,4))
gs2 = fig.add_gridspec(nrows=5, ncols=1, wspace=0.05,hspace=-0.40)
f_ax2 = fig.add_subplot(gs2[:-1, 0])
plt.title('Input')
plt.imshow(D, cmap='gray')
plt.xticks([])
plt.yticks([])
f_ax3 = fig.add_subplot(gs2[-1, 0])
plt.plot(radar_data)
plt.xticks([])
plt.title('Radar Return',y=-.05)
# plt.savefig('sensor_disagree_1.png')
plt.show()

plt.imshow(radar_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.title('Sparse Output')
plt.tight_layout()
# plt.savefig('sensor_disagree_2.png')
plt.show()

# %%
plt.imshow(D, cmap='gray')
plt.plot(-radar_data*100+228,color='lime',linestyle='-',linewidth=4)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('disagree_overlay.png',bbox_inches='tight')

# %%
plt.figure(figsize=(10,2))
plt.plot(radar_data)
plt.grid()
plt.xticks([])
plt.savefig('disagree_radar.png',bbox_inches='tight')

# %%
plt.imshow(radar_2, cmap='gray', vmin=0, vmax=1)
plt.xticks([])
plt.yticks([])
plt.savefig('disagree_sparse.png',bbox_inches='tight')

# %%
idx = 0
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_b_0.png',bbox_inches='tight')

# %%
idx = 10
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_b_10.png',bbox_inches='tight')

# %%
idx = 20
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_700/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_b_20.png',bbox_inches='tight')

# %%
idx = 0
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_a_0.png',bbox_inches='tight')

# %%
idx = 10
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_a_10.png',bbox_inches='tight')

# %%
idx = 20
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_lobby_side_0/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_a_20.png',bbox_inches='tight')

# %%
idx = 0
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_c_0.png',bbox_inches='tight')

# %%
idx = 10
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_c_10.png',bbox_inches='tight')

# %%
idx = 20
radar_data = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/radar_likelihoods.npy')[idx]
radar_data = rescale(radar_data,.25,anti_aliasing=True)
D = np.load('/home/spencer/research/radar-rgb-bfs/Data/CSL_pantry/raw/D.npy')[idx]
D = rescale(D,(.25,.25),anti_aliasing=True)

plt.imshow(D, cmap='gray')
plt.plot(-radar_data*50+182,color='lime',linestyle='-',linewidth=3)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig('scene_c_20.png',bbox_inches='tight')
